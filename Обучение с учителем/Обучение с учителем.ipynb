# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#мы-нашли-пропуски-в-в-столбце-Tenure-по-всей-вероятности-пропуски-означают-что-количество-недвижимости-у-клиента-равно-0.пропуски-заменили-на-0-и-поменяли-на-инт." data-toc-modified-id="мы-нашли-пропуски-в-в-столбце-Tenure-по-всей-вероятности-пропуски-означают-что-количество-недвижимости-у-клиента-равно-0.пропуски-заменили-на-0-и-поменяли-на-инт.-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>мы нашли пропуски в в столбце Tenure по всей вероятности пропуски означают что количество недвижимости у клиента равно 0.пропуски заменили на 0 и поменяли на инт.</a></span></li><li><span><a href="#столбец-RowNumber-индекс-строки-у-нас-повторяется-и-что-бы-не-мешалось-удалили-столбец." data-toc-modified-id="столбец-RowNumber-индекс-строки-у-нас-повторяется-и-что-бы-не-мешалось-удалили-столбец.-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>столбец RowNumber индекс строки у нас повторяется и что бы не мешалось удалили столбец.</a></span></li><li><span><a href="#дубликатов-нет" data-toc-modified-id="дубликатов-нет-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>дубликатов нет</a></span></li><li><span><a href="#столбец-'RowNumber','Surname','CustomerId'-удалили-так-как-они-будут-мешатся-и-неизвестно-какие-либо-зависимости-от-них" data-toc-modified-id="столбец-'RowNumber','Surname','CustomerId'-удалили-так-как-они-будут-мешатся-и-неизвестно-какие-либо-зависимости-от-них-2.0.4"><span class="toc-item-num">2.0.4&nbsp;&nbsp;</span>столбец 'RowNumber','Surname','CustomerId' удалили так как они будут мешатся и неизвестно какие либо зависимости от них</a></span></li><li><span><a href="#Избавились-от-категориальных-признаков" data-toc-modified-id="Избавились-от-категориальных-признаков-2.0.5"><span class="toc-item-num">2.0.5&nbsp;&nbsp;</span>Избавились от категориальных признаков</a></span></li><li><span><a href="#Разбили-на-тренировочную,-тестовую-и-валидационную-выборки" data-toc-modified-id="Разбили-на-тренировочную,-тестовую-и-валидационную-выборки-2.0.6"><span class="toc-item-num">2.0.6&nbsp;&nbsp;</span>Разбили на тренировочную, тестовую и валидационную выборки</a></span></li><li><span><a href="#Имеется-дисбаланс-классов.-1:4-в-пользу-оставшихся-клиентов" data-toc-modified-id="Имеется-дисбаланс-классов.-1:4-в-пользу-оставшихся-клиентов-2.0.7"><span class="toc-item-num">2.0.7&nbsp;&nbsp;</span>Имеется дисбаланс классов. 1:4 в пользу оставшихся клиентов</a></span></li><li><span><a href="#без-учета-дисбаланса-f1-дает-очень-слабые-резултаты-.-самое-лучшее-модель-случайного-леса-n_estimators-=-x-Max-depth-y-в-гиперпараметрах-далее-попробуем-решить-проблему-с-дисбалансом" data-toc-modified-id="без-учета-дисбаланса-f1-дает-очень-слабые-резултаты-.-самое-лучшее-модель-случайного-леса-n_estimators-=-x-Max-depth-y-в-гиперпараметрах-далее-попробуем-решить-проблему-с-дисбалансом-2.0.8"><span class="toc-item-num">2.0.8&nbsp;&nbsp;</span>без учета дисбаланса f1 дает очень слабые резултаты . самое лучшее модель случайного леса n_estimators = x Max depth y в гиперпараметрах далее попробуем решить проблему с дисбалансом</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#вывод-по-проекту:" data-toc-modified-id="вывод-по-проекту:-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>вывод по проекту:</a></span></li></ul></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [raw]
# Описание данных:
# RowNumber — индекс строки в данных
# CustomerId — уникальный идентификатор клиента
# Surname — фамилия
# CreditScore — кредитный рейтинг
# Geography — страна проживания
# Gender — пол
# Age — возраст
# Tenure — количество недвижимости у клиента
# Balance — баланс на счёте
# NumOfProducts — количество продуктов банка, используемых клиентом
# HasCrCard — наличие кредитной карты
# IsActiveMember — активность клиента
# EstimatedSalary — предполагаемая зарплата
# Exited — факт ухода клиента

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score,classification_report,confusion_matrix, f1_score,roc_auc_score, roc_curve,accuracy_score, mean_squared_error
#from sklearn.metrics import confusion_matrix, f1_score
#from sklearn.metrics import roc_auc_score, roc_curve
#from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.metrics import confusion_matrix

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
try:
    data = pd.read_csv('/datasets/Churn.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/Churn.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
data['Tenure'].unique()
# Out:
# array([ 2.,  1.,  8.,  7.,  4.,  6.,  3., 10.,  5.,  9.,  0., nan])

# %%
data[data['Tenure'].isna()==True]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 30           31    15589475    Azikiwe          591     Spain  Female   39
# 48           49    15766205        Yin          550   Germany    Male   38
# 51           52    15768193  Trevisani          585   Germany    Male   36
# 53           54    15702298   Parkhill          655   Germany    Male   41
# 60           61    15651280     Hunter          742   Germany    Male   35
# ...         ...         ...        ...          ...       ...     ...  ...
# 9944       9945    15703923    Cameron          744   Germany    Male   41
# 9956       9957    15707861      Nucci          520    France  Female   46
# 9964       9965    15642785    Douglas          479    France    Male   34
# 9985       9986    15586914     Nepean          659    France    Male   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data['Tenure']=(data['Tenure'].fillna(data['Tenure'].median())).astype('int64')

# %%
data=data.drop(['RowNumber','Surname','CustomerId'], axis=1)

# %%
# Избавляюсь от категориальных признаков
data = pd.get_dummies(data, drop_first=True)
data.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
data.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe().T
# Out:
#                      count           mean           std     min       25%  \
# CreditScore        10000.0     650.528800     96.653299  350.00    584.00
# Age                10000.0      38.921800     10.487806   18.00     32.00
# Tenure             10000.0       4.997900      2.760010    0.00      3.00
# Balance            10000.0   76485.889288  62397.405202    0.00      0.00
# NumOfProducts      10000.0       1.530200      0.581654    1.00      1.00
# HasCrCard          10000.0       0.705500      0.455840    0.00      0.00
# IsActiveMember     10000.0       0.515100      0.499797    0.00      0.00
# EstimatedSalary    10000.0  100090.239881  57510.492818   11.58  51002.11
# Exited             10000.0       0.203700      0.402769    0.00      0.00
# Geography_Germany  10000.0       0.250900      0.433553    0.00      0.00
# Geography_Spain    10000.0       0.247700      0.431698    0.00      0.00
# Gender_Male        10000.0       0.545700      0.497932    0.00      0.00
#
# ...

# %%
RANDOM_STATE=12345

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        10000 non-null  int64
#  1   Age                10000 non-null  int64
#  2   Tenure             10000 non-null  int64
#  3   Balance            10000 non-null  float64
#  4   NumOfProducts      10000 non-null  int64
#  5   HasCrCard          10000 non-null  int64
#  6   IsActiveMember     10000 non-null  int64
#  7   EstimatedSalary    10000 non-null  float64
#  8   Exited             10000 non-null  int64
#  9   Geography_Germany  10000 non-null  uint8
#  10  Geography_Spain    10000 non-null  uint8
#  11  Gender_Male        10000 non-null  uint8
# dtypes: float64(2), int64(7), uint8(3)
# memory usage: 732.5 KB

# %%
# Разбиваем на тренировочную, тестовую и валидационную выборки

target = data['Exited']
features = data.drop('Exited', axis=1)

f_train, f_valid, t_train, t_valid = train_test_split(features, target, test_size=0.4, 
                                                                              random_state=RANDOM_STATE)#,stratify=t_valid
f_valid, f_test, t_valid, t_test = train_test_split(f_valid, t_valid, test_size=0.5, 
                                                                              random_state=RANDOM_STATE)#,stratify=t_valid
print(f_train.shape, f_valid.shape, f_test.shape)
print(t_train.shape, t_valid.shape, t_test.shape)
# print(f"Количество строк в target по классам: {np.bincount(target)}")
# print(f"Количество строк в t_valid по классам: {np.bincount(t_valid)}")
# Out:
# (6000, 11) (2000, 11) (2000, 11)
# (6000,) (2000,) (2000,)

# %%
sns.pairplot(data)
plt.show()

# %%
# Масштабируем численные признаки выборок для выравнивания весов
numeric=['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
scaler=StandardScaler()
scaler.fit(f_train[numeric])
f_train[numeric]=scaler.transform(f_train[numeric])
f_valid[numeric]=scaler.transform(f_valid[numeric])
f_test[numeric]=scaler.transform(f_test[numeric])
f_train.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 7479    -0.886751 -0.373192  1.082277  1.232271      -0.891560          1
# 3411     0.608663 -0.183385  1.082277  0.600563      -0.891560          0
# 6027     2.052152  0.480939 -0.737696  1.027098       0.830152          0
# 1247    -1.457915 -1.417129  0.354288 -1.233163       0.830152          1
# 3716     0.130961 -1.132419 -1.101690  1.140475      -0.891560          0
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 7479               0        -0.187705                  0                1
# 3411               0        -0.333945                  0                0
# 6027               1         1.503095                  1                0
# 1247               0        -1.071061                  0                0
# 3716               0         1.524268                  1                0
#
#       Gender_Male
# 7479            1
# 3411            0
# ...

# %% [markdown]
# ## Исследование задачи

# %%
data['Exited'].value_counts().plot(kind='bar', grid=True,figsize=(10,5),title='Соотношение ушедших к оставшимся клиентам');
data['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [raw]
# Обучение моделей:
# Решающее дерево
# Случайный лес
# Логистическая регрессия

# %% [markdown]
# Обучим модели случайного дерева

# %%
f1_best = 0
depth_best = 0
for depth in range(1, 21,3):
    model = DecisionTreeClassifier(random_state=RANDOM_STATE, max_depth=depth)
    model.fit(f_train, t_train)
    prediction = model.predict(f_valid)
    f1 = f1_score(t_valid, prediction)
    if f1>f1_best:
            f1_best=f1
            depth_best=depth
print('Max depth', depth_best,'F1-score', f1_best)
# Out:
# Max depth 4 F1-score 0.5528700906344411

# %%
#Проведем оценку accuracy, precision, recall, F1, AUC-ROC на полученных гиперпараметрах
model = DecisionTreeClassifier(random_state=RANDOM_STATE, max_depth=depth_best)
model.fit(f_train, t_train)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# Out:
# F1 0.5528700906344411
# AUC-ROC 0.813428129858032

# %% [markdown]
# Обучение модели случайного леса

# %%
f1_best = 0
estim_best = 0
depth_best = 0

for estim in range (120,125,3):
    for depth in range(9,11):
        model = RandomForestClassifier(n_estimators=estim, max_depth=depth, random_state=RANDOM_STATE)
        model.fit(f_train, t_train)
        prediction = model.predict(f_valid)
        f1 = f1_score(t_valid, prediction)
        if f1>f1_best:
            f1_best=f1
            estim_best=estim
            depth_best=depth
        

print('n_estimators =', estim_best, 'Max depth', depth_best, 'F1-score', f1_best)
# Out:
# n_estimators = 120 Max depth 10 F1-score 0.5842349304482226

# %%
model = RandomForestClassifier(n_estimators=estim_best, max_depth=depth_best, random_state=RANDOM_STATE)
model.fit(f_train, t_train)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
# print(classification_report(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('F1', f1_score(t_valid, prediction))
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# Out:
# F1 0.5842349304482226
# AUC-ROC 0.851716983528814

# %% [markdown]
# Обучение модели Логистической регрессии

# %%
model =  LogisticRegression()
model.fit(f_train, t_train)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# Out:
# F1 0.33108108108108103
# AUC-ROC 0.7588026784580114

# %% [markdown]
# # вывод
# #### мы нашли пропуски в в столбце Tenure по всей вероятности пропуски означают что количество недвижимости у клиента равно 0.пропуски заменили на 0 и поменяли на инт.
# #### столбец RowNumber индекс строки у нас повторяется и что бы не мешалось удалили столбец.
# #### дубликатов нет
# #### столбец 'RowNumber','Surname','CustomerId' удалили так как они будут мешатся и неизвестно какие либо зависимости от них
# ####  Избавились от категориальных признаков
# #### Разбили на тренировочную, тестовую и валидационную выборки
# #### Имеется дисбаланс классов. 1:4 в пользу оставшихся клиентов
# #### без учета дисбаланса f1 дает очень слабые резултаты . самое лучшее модель случайного леса n_estimators = x Max depth y в гиперпараметрах далее попробуем решить проблему с дисбалансом

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# 1 в гиперпараметрах

# %%
#Обучим модели случайного дерева
f1_best = 0
depth_best = 0
for depth in range(1, 21,3):
    model = DecisionTreeClassifier(random_state=RANDOM_STATE, max_depth=depth, class_weight='balanced')
    model.fit(f_train, t_train)
    prediction = model.predict(f_valid)
    f1 = f1_score(t_valid, prediction)
    if f1>f1_best:
            f1_best=f1
            depth_best=depth
print('Max depth', depth_best,'F1-score', f1_best)

#Проведем оценку accuracy, precision, recall, F1, AUC-ROC на полученных гиперпараметрах
model = DecisionTreeClassifier(random_state=RANDOM_STATE, max_depth=depth_best, class_weight='balanced')
model.fit(f_train, t_train)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# Out:
# Max depth 7 F1-score 0.5508390918065154
# F1 0.5508390918065154
# AUC-ROC 0.7942001524325698

# %%
#Обучение модели случайного леса
f1_best = 0
estim_best = 0
depth_best = 0

for estim in range (120,125,3):#148
    for depth in range(7,11):#12
        model = RandomForestClassifier(n_estimators=estim, max_depth=depth, random_state=RANDOM_STATE, class_weight='balanced')
        model.fit(f_train, t_train)
        prediction = model.predict(f_valid)
        f1 = f1_score(t_valid, prediction)
        if f1>f1_best:
            f1_best=f1
            estim_best=estim
            depth_best=depth
        

print('n_estimators =', estim_best, 'Max depth', depth_best, 'F1-score', f1_best)

model = RandomForestClassifier(n_estimators=estim_best, max_depth=depth_best, random_state=RANDOM_STATE, class_weight='balanced')
model.fit(f_train, t_train)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# Out:
# n_estimators = 123 Max depth 9 F1-score 0.6344827586206896
# F1 0.6344827586206896
# AUC-ROC 0.8566922132362284

# %%
#Обучение модели Логистической регрессии
model =  LogisticRegression(class_weight='balanced')
model.fit(f_train, t_train)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# print(confusion_matrix(t_valid, prediction))
# Out:
# F1 0.4888507718696398
# AUC-ROC 0.7636811255814515

# %% [markdown]
# 2 уменьшим колличество target=0

# %%
def downsampling(features,target,fraction):
    features_null=features[target==0]
    features_one=features[target==1]
    target_null=target[target==0]
    target_one=target[target==1]
    downsampling_features=pd.concat([features_null.sample(frac=fraction,random_state=RANDOM_STATE)]+[features_one])
    downsampling_target=pd.concat([target_null.sample(frac=fraction,random_state=RANDOM_STATE)]+[target_one])
    downsampling_features,downsampling_target=shuffle(downsampling_features,downsampling_target,random_state=12345)
    return downsampling_features,downsampling_target
features_balance,target_balance=downsampling(features,target,0.25)

# %% [markdown]
# пробуем случайного дерева

# %%
#пробуем случайного дерева
f1_best = 0
depth_best = 0
for depth in range(1,21,3):
    model = DecisionTreeClassifier(random_state=RANDOM_STATE, max_depth=depth)
    model.fit(features_balance, target_balance)
    prediction = model.predict(f_valid)
    f1 = f1_score(t_valid, prediction)
    if f1>f1_best:
            f1_best=f1
            depth_best=depth
print('Max depth', depth_best,'F1-score', f1_best)

#Проведем оценку accuracy, precision, recall, F1, AUC-ROC на полученных гиперпараметрах
model = DecisionTreeClassifier(random_state=RANDOM_STATE, max_depth=depth_best)
model.fit(features_balance, target_balance)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# Out:
# Max depth 4 F1-score 0.4020304568527919
# F1 0.4020304568527919
# AUC-ROC 0.6354404212461968

# %%
#Обучение модели случайного леса
f1_best = 0
estim_best = 0
depth_best = 0

for estim in range (121,130,3):#66
    for depth in range(1,21,3):#12
        model = RandomForestClassifier(n_estimators=estim, max_depth=depth, random_state=RANDOM_STATE)
        model.fit(features_balance, target_balance)
        prediction = model.predict(f_valid)
        f1 = f1_score(t_valid, prediction)
        if f1>f1_best:
            f1_best=f1
            estim_best=estim
            depth_best=depth
        

print('n_estimators =', estim_best, 'Max depth', depth_best, 'F1-score', f1_best)

model = RandomForestClassifier(n_estimators=estim_best, max_depth=depth_best, random_state=RANDOM_STATE)
model.fit(features_balance, target_balance)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# Out:
# n_estimators = 121 Max depth 4 F1-score 0.4326672458731538
# F1 0.4326672458731538
# AUC-ROC 0.6910510891065152

# %%
#Обучение модели Логистической регрессии
model =  LogisticRegression()
model.fit(features_balance, target_balance)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# print(confusion_matrix(t_valid, prediction))
# Out:
# F1 0.4822695035460993
# AUC-ROC 0.7452062376375372

# %% [markdown]
# увеличим количество колличество target=0

# %%
def upsampling (features,target,repeat):
    target_one=target[target==1]
    target_null=target[target==0]
    features_one=features[target==1]
    features_null=features[target==0]
    upsampling_features=pd.concat([features_null]+[features_one]*repeat)
    upsampling_target=pd.concat([target_null]+[target_one]*repeat)
    upsampling_features,upsampling_target=shuffle(upsampling_features,upsampling_target,random_state=RANDOM_STATE)
    return upsampling_features,upsampling_target
features_balance,target_balance=upsampling(f_train,t_train,4)#??????????

# %%
#пробуем случайного дерева
f1_best = 0
depth_best = 0
for depth in range(1,21,3):
    model = DecisionTreeClassifier(random_state=RANDOM_STATE, max_depth=depth)
    model.fit(features_balance, target_balance)
    prediction = model.predict(f_valid)
    f1 = f1_score(t_valid, prediction)
    if f1>f1_best:
            f1_best=f1
            depth_best=depth
print('Max depth', depth_best,'F1-score', f1_best)

model = DecisionTreeClassifier(random_state=RANDOM_STATE, max_depth=depth_best)
model.fit(features_balance, target_balance)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# Out:
# Max depth 7 F1-score 0.5524752475247525
# F1 0.5524752475247525
# AUC-ROC 0.7949464368886818

# %%
#Обучение модели Логистической регрессии
model =  LogisticRegression()
model.fit(features_balance, target_balance)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# print(confusion_matrix(t_valid, prediction))
# Out:
# F1 0.4888507718696398
# AUC-ROC 0.7636206364664678

# %%
#Обучение модели случайного леса
f1_best = 0
estim_best = 0
depth_best = 0

for estim in range (120, 126,3):#66
    for depth in range(7,9):#12
        model = RandomForestClassifier(n_estimators=estim, max_depth=depth, random_state=RANDOM_STATE)
        model.fit(features_balance, target_balance)
        prediction = model.predict(f_valid)
        f1 = f1_score(t_valid, prediction)
        if f1>f1_best:
            f1_best=f1
            estim_best=estim
            depth_best=depth
        

print('n_estimators =', estim_best, 'Max depth', depth_best, 'F1-score', f1_best)

model = RandomForestClassifier(n_estimators=estim_best, max_depth=depth_best, random_state=RANDOM_STATE)
model.fit(features_balance, target_balance)
prediction = model.predict(f_valid)
# print('Accuracy', accuracy_score(t_valid, prediction))
# print('Precision', precision_score(t_valid, prediction))
# print('Recall', recall_score(t_valid, prediction))
print('F1', f1_score(t_valid, prediction))
probabilities_valid = model.predict_proba(f_valid)[:, 1]
print('AUC-ROC', roc_auc_score(t_valid, probabilities_valid))
# print(classification_report(t_valid, prediction))
# Out:
# n_estimators = 123 Max depth 7 F1-score 0.6158475426278835
# F1 0.6158475426278835
# AUC-ROC 0.8551678875386375

# %% [markdown]
# лучшые резулататы f1 auc-roc дала модель слчайного леса с гиперпараметрами balansed с подбором глубыни и колчество деревев.

# %% [markdown]
# ## Тестирование модели

# %%
model = RandomForestClassifier(n_estimators=123, max_depth=7, random_state=RANDOM_STATE)
model.fit(features_balance, target_balance)
prediction = model.predict(f_test)
# print('Accuracy', accuracy_score(t_test, prediction))
# print('Precision', precision_score(t_test, prediction))
# print('Recall', recall_score(t_test, prediction))
print('F1', f1_score(t_test, prediction))
probabilities_valid = model.predict_proba(f_test)[:, 1]
print('AUC-ROC', roc_auc_score(t_test, probabilities_valid))
fpr2, tpr2, thresholds2 = roc_curve(t_test, probabilities_valid)
# print(classification_report(t_test, prediction))
# print(confusion_matrix(t_test, prediction))
# Out:
# F1 0.6025768087215064
# AUC-ROC 0.852993159648673

# %%
model_final = RandomForestClassifier(n_estimators=123, max_depth=9, random_state=RANDOM_STATE, class_weight='balanced')
model_final.fit(f_train, t_train)
prediction = model_final.predict(f_test)
# print('Accuracy', accuracy_score(t_test, prediction))
# print('Precision', precision_score(t_test, prediction))
# print('Recall', recall_score(t_test, prediction))
print('F1', f1_score(t_test, prediction))
probabilities_valid = model_final.predict_proba(f_test)[:, 1]
print("AUC-ROC", roc_auc_score(t_test, probabilities_valid))
fpr, tpr, thresholds = roc_curve(t_test, probabilities_valid)
# print(classification_report(t_test, prediction))
# print(confusion_matrix(t_test, prediction))
# Out:
# F1 0.6090909090909091
# AUC-ROC 0.8570407048125314

# %%
plt.figure();

plt.figure(figsize=(10,4))
plt.plot([0, 1], [0, 1])
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot(fpr,tpr)

plt.plot(fpr2,tpr2)
plt.plot(fpr,tpr)


plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC')
plt.legend(('Случайная модель','Тестируемая модель','Тестируемая модель 2'),
           loc= 'upper left') 
plt.show()

# %% [markdown]
# мы видим 2 лучшых резултата с разнымы способами балансировки которые приблизительно одинаковы ф1 мера выше 0.59.

# %% [markdown]
# #### вывод по проекту:
# мы прочитали данные из Churn.csv получилось  12 столбцов и 10000 строк. в стобце Tenure заменили пропуски на медиану и удалили из данных столбцы  'RowNumber','Surname','CustomerId' масштабировали данныею одным словом подготовили данные. дальше разделили данные 3:1:1 размером и так как в данных был дисбаланс попробовали разными спосабами решить вопрос.нашли наилучшую модель с самым высоким f1 параметром их оказалос 2 практически одинаковых. получили f1 выше 0.59 это нас полночтю устраивает)))
