# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import datetime

# %% [markdown]
# # Сборный проект

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры.
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов,
#  жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности.
# Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й.
#  Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го
# или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация,
# определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную
# категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
# Инструкция по выполнению проекта
#
# ## Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/games.csv. Скачать датасет
#
# ## Шаг 2. Подготовьте данные
# Замените названия столбцов (приведите к нижнему регистру);
# Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# Обработайте пропуски при необходимости:
# Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# Опишите причины, которые могли привести к пропускам;
# Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите,
#  как его обработать;
# Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# ## Шаг 3. Проведите исследовательский анализ данных
# XПосмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте
#  распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате
#  исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# Не учитывайте в работе данные за предыдущие годы.
# Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте
#  диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# Соотнесите выводы с продажами игр на других платформах.
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры
# с высокими и низкими продажами?
#
# ## Шаг 4. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
# Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# Самые популярные жанры (топ-5). Поясните разницу.
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# ## Шаг 5. Проверьте гипотезы
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования»)
#  разные.
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.
#
# ## Шаг 6. Напишите общий вывод
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code,
# текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
#
# ## Описание данных
#
#
# Name — название игры
# Platform — платформа
# Year_of_Release — год выпуска
# Genre — жанр игры
# NA_sales — продажи в Северной Америке (миллионы проданных копий)
# EU_sales — продажи в Европе (миллионы проданных копий)
# JP_sales — продажи в Японии (миллионы проданных копий)
# Other_sales — продажи в других странах (миллионы проданных копий)
# Critic_Score — оценка критиков (максимум 100)
# User_Score — оценка пользователей (максимум 10)
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет
#  рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
# Данные за 2016 год могут быть неполными.
# Как будут проверять мой проект?
# Мы подготовили критерии оценки проекта. Прежде чем решать кейс, внимательно изучите их.
# На что обращают внимание при проверке проекта:
# Как вы описываете выявленные в данных проблемы?
# Как готовите датасет к анализу?
# Какие строите графики для распределений и как их объясняете?
# Формулируете ли альтернативную и нулевую гипотезы?
# Какие методы применяете, чтобы их проверить?
# Объясняете результат проверки гипотезы или нет?
# Соблюдаете ли структуру проекта и поддерживаете аккуратность кода?
# Какие выводы делаете?
# Оставляете ли комментарии к шагам?
# Всё необходимое, чтобы выполнить проект, есть в шпаргалках и конспектах прошлых тем.
# Успехов!

# %% [markdown]
# # Шаг 1.общая информация

# %%
try:
    data = pd.read_csv('/datasets/games.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')

# %%
data.head()#проверяем корректонсть данных
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.tail()#проверяем корректонсть данных
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16711               LMA Manager 2007     X360           2006.0      Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16713               Spirits & Spells      GBA           2003.0    Platform
# 16714            Winning Post 8 2016      PSV           2016.0  Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 16710      0.00      0.00      0.01          0.0           NaN        NaN
# 16711      0.00      0.01      0.00          0.0           NaN        NaN
# 16712      0.00      0.00      0.01          0.0           NaN        NaN
# 16713      0.01      0.00      0.00          0.0           NaN        NaN
# 16714      0.00      0.00      0.01          0.0           NaN        NaN
#
#       Rating
# 16710    NaN
# 16711    NaN
# 16712    NaN
# ...

# %% [markdown]
# видно что в названиях столбцов есть большые буквы нужно будет поменять

# %%
data.info()#смотрим информацию о данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# видем что в столбцах  Name Year_of_Release  Genre Critic_Score User_Score Rating нехватает данных

# %% [markdown]
# в столбце Year_of_Release явно не должно быть флоат поменяем хотя бы на инт

# %% [markdown]
# User_Score Rating поменяем на float  что бы можно было с ним работать

# %%
data.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# выдим в столбцах NA_sales EU_sales 	Other_sales большую разницу между средным и медианным значенями а в JP_sales вообше медиана равно 0 пердстоит все проверить

# %%
data.shape
# Out:
# (16715, 11)

# %%
data.duplicated().sum()#дупликатов нет
# Out:
# 0

# %%
data.isna().sum()#смотрим количество пропусков встолбцах
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %%
data.columns#смотрим название столбцов
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %% [markdown]
# data.hist(figsize=(15, 20));

# %% [markdown]
# план работы:
# 1.переименуем столбцы в нижный регистр
# 2.разбираемся с пропусками в каждом столбце где они есть Name Year_of_Release Genre Critic_Score
# 3.меняем типи данных
#        в столбце Year_of_Release явно не должно быть флоат поменяем хотя бы на инт
#        NA_sales  EU_sales JP_sales Other_sales тоже поменяем на инт что бы удобнее было сними работать(по количеству штук а не        милионы)
#        User_Score Rating поменяем на float  что бы можно было с ним работать
# 4.проверяем все стобцы индивидульно
# 5.делаем выводи

# %% [markdown]
# ## Шаг 2. Подготовка данных

# %% [markdown]
# ### меняем на нижный регистр название столбцов

# %%
data.columns = data.columns.str.lower()#меняем на нижный регистр название столбцов

# %%
data.columns#проверка
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# ### разбираемся с пропусками в каждом столбце где они есть Name Year_of_Release Genre Critic_Score User_Score Rating

# %% [markdown]
# ### столбец name

# %%
data['name'].isna().sum()
# Out:
# 2

# %%
data[data['name'].isna()==True]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %%
data = data.dropna(subset = ['name'])#удаляем данные так как их мало и в этих строках в других столбцах тоже много проусков

# %%
data['name'].isna().sum()
# Out:
# 0

# %%
data['name'] = data['name'].str.lower()#приведем все к нижнему регистру мало ли... может там невнимательно написали название

# %% [markdown]
# ### за одно удалились пропуски в столбце genre

# %%
data['genre'].isna().sum()
# Out:
# 0

# %% [markdown]
# data['platform'].unique()

# %% [markdown]
# ### столбец year_of_release

# %%
data['year_of_release'].head()
# Out:
# 0    2006.0
# 1    1985.0
# 2    2008.0
# 3    2009.0
# 4    1996.0
# Name: year_of_release, dtype: float64

# %%
data['year_of_release'].isna().sum()#смотрим пропуски
# Out:
# 269

# %%
data['year_of_release'].unique()#все хорошо главное не забыть в инт перефигачить
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %%
data[data['year_of_release'].isna()==True].head(20)
# Out:
#                                              name platform  year_of_release  \
# 183                               madden nfl 2004      PS2              NaN
# 377                              fifa soccer 2004      PS2              NaN
# 456                    lego batman: the videogame      Wii              NaN
# 475                    wwe smackdown vs. raw 2006      PS2              NaN
# 609                                space invaders     2600              NaN
# 627                                     rock band     X360              NaN
# 657      frogger's adventures: temple of the frog      GBA              NaN
# 678   lego indiana jones: the original adventures      Wii              NaN
# 719                                call of duty 3      Wii              NaN
# 805                                     rock band      Wii              NaN
# 1131                      call of duty: black ops       PC              NaN
# ...

# %% [markdown]
# заполним пропуски медианой по групам имени по логике должно быть незначительная разница

# %%
data['year_of_release']=data['year_of_release'].fillna(data.groupby('name')['year_of_release'].transform('median'))

# %%
data['year_of_release'].isna().sum()#проверка осталось 146 пропусков
# Out:
# 146

# %% [markdown]
# остались те у которых ни на одной платформе нет года выпуска.можем отсюда еше найти пару штук где в названиях написана год выпуска но это капли в море тем более и в других столбцах много пропусков. так что удаляем остальное

# %%
data = data.dropna(subset = ['year_of_release'])

# %%
data['year_of_release'].isna().sum()
# Out:
# 0

# %%
data['year_of_release']=data['year_of_release'].astype('int')

# %%
data['year_of_release'].unique()
# Out:
# array([2006, 1985, 2008, 2009, 1996, 1989, 1984, 2005, 1999, 2007, 2010,
#        2013, 2004, 1990, 1988, 2002, 2001, 2011, 1998, 2015, 2012, 2014,
#        1992, 1997, 1993, 1994, 1982, 2016, 2003, 1986, 2000, 1995, 1991,
#        1981, 1987, 1980, 1983])

# %% [markdown]
# Шикарно

# %% [markdown]
# ### столбец user_score

# %%
data['user_score'].describe()
# Out:
# count     9934
# unique      96
# top        tbd
# freq      2394
# Name: user_score, dtype: object

# %%
data['user_score'].unique()#похоже тут средная оценка игры так что оставим float разберемся с пропусками и tbd
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
data['user_score'].isna().sum()
# Out:
# 6633

# %% [markdown]
# совподения???? не думаю!!!TBD. To Be Decided или To Be Determined TBD. Будет определено.так как пропусков много что бы удалить заменим на медиану по игре остальное по платформе а TBD заменим на пропуск и обработаем ка пропуск

# %%
data.loc[data['user_score'] =='tbd','user_score'] = np.nan

# %%
data[data['user_score'].isna()==True]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  super mario bros.      NES             1985      Platform
# 4           pokemon red/pokemon blue       GB             1996  Role-Playing
# 5                             tetris       GB             1989        Puzzle
# 9                          duck hunt      NES             1984       Shooter
# 10                        nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16710  samurai warriors: sanada maru      PS3             2016        Action
# 16711               lma manager 2007     X360             2006        Sports
# 16712        haitaka no psychedelica      PSV             2016     Adventure
# 16713               spirits & spells      GBA             2003      Platform
# 16714            winning post 8 2016      PSV             2016    Simulation
#
# ...

# %%
data['user_score'].isna().sum()
# Out:
# 9027

# %%
data['user_score']=data['user_score'].astype('float')

# %%
data['user_score']=data['user_score'].fillna(data.groupby('name')['user_score'].transform('median'))

# %% [markdown]
# data['user_score']=data['user_score'].fillna('tbd')

# %%
data['user_score'].isna().sum()
# Out:
# 7928

# %% [markdown]
# ### столбец critic_score

# %%
data['critic_score'].isna().sum()
# Out:
# 8492

# %%
data['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 13.])

# %%
data['critic_score']=data['critic_score'].fillna(data.groupby('name')['critic_score'].transform('median'))

# %% [markdown]
# data['critic_score']=data['critic_score'].fillna('tbd')

# %%
data['critic_score'].isna().sum()
# Out:
# 7532

# %%
data['critic_score'].unique()
# Out:
# array([76. ,  nan, 82. , 80. , 89. , 58. , 87. , 91. , 61. , 97. , 95. ,
#        77. , 88. , 83. , 94. , 93. , 85. , 86. , 98. , 96. , 90. , 84. ,
#        73. , 74. , 78. , 92. , 71. , 72. , 68. , 62. , 49. , 42. , 67. ,
#        81. , 66. , 56. , 43. , 79. , 70. , 59. , 64. , 75. , 60. , 63. ,
#        62.5, 69. , 50. , 25. , 44. , 55. , 80.5, 48. , 75.5, 57. , 29. ,
#        74.5, 47. , 65. , 77.5, 54. , 20. , 61.5, 53. , 37. , 52. , 82.5,
#        38. , 33. , 30. , 32. , 53.5, 45. , 51. , 68.5, 40. , 46. , 83.5,
#        86.5, 85.5, 39. , 73.5, 70.5, 34. , 96.5, 57.5, 59.5, 65.5, 90.5,
#        69.5, 35. , 81.5, 41. , 54.5, 92.5, 88.5, 72.5, 36. , 78.5, 89.5,
#        44.5, 60.5, 40.5, 28. , 87.5, 31. , 27. , 26. , 67.5, 19. , 71.5,
#        66.5, 23. , 39.5, 91.5, 31.5, 42.5, 24. , 21. , 35.5, 49.5, 52.5,
#        17. , 79.5, 19.5, 48.5, 28.5, 63.5, 58.5, 56.5, 50.5, 13. , 64.5,
#        76.5])

# %% [markdown]
# ### столбец rating

# %% [markdown]
# ###здесь мы преоброзуем данные что бы с нтми можно было работать. потом пропуски заменим на те которые максимально много по названию. думаю что категория игры примерно должна быть одинаковая для игры на разных платформах. далее пропуски поменяем на максимальное значение по жанру так же они должны совпадать хотя бы примерно.

# %%
data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
data['rating']=data['rating'].fillna("Unknown")

# %% [markdown]
# data['rating']=data['rating'].astype('string')

# %% [markdown]
# data.loc[data['rating'] =='nan','rating'] = np.nan

# %%
data['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# data['rating']=data['rating'].astype('str')

# %% [markdown]
# data['rating']=data['rating'].fillna(data.groupby('name')['rating'].transform('max'))

# %% [markdown]
# data['rating'].isna().sum()

# %% [markdown]
# data['rating']=data['rating'].fillna(data.groupby('genre')['rating'].transform('max'))

# %%
data['rating'].isna().sum()
# Out:
# 0

# %%
data['rating'].unique()
# Out:
# array(['E', 'Unknown', 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'],
#       dtype=object)

# %%
data['rating'].value_counts()
# Out:
# Unknown    6699
# E          3958
# T          2930
# M          1554
# E10+       1412
# EC            8
# K-A           3
# RP            2
# AO            1
# Name: rating, dtype: int64

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      Wii             2006        Sports     41.36
# 1         super mario bros.      NES             1985      Platform     29.08
# 2            mario kart wii      Wii             2008        Racing     15.68
# 3         wii sports resort      Wii             2009        Sports     15.61
# 4  pokemon red/pokemon blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating
# 0     28.96      3.77         8.45          76.0         8.0        E
# 1      3.58      6.81         0.77           NaN         NaN  Unknown
# 2     12.76      3.79         3.29          82.0         8.3        E
# 3     10.93      3.28         2.95          80.0         8.0        E
# 4      8.89     10.22         1.00           NaN         NaN  Unknown

# %% [markdown]
# data['rating']=data['rating'].astype('object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16567 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16567 non-null  object
#  1   platform         16567 non-null  object
#  2   year_of_release  16567 non-null  int64
#  3   genre            16567 non-null  object
#  4   na_sales         16567 non-null  float64
#  5   eu_sales         16567 non-null  float64
#  6   jp_sales         16567 non-null  float64
#  7   other_sales      16567 non-null  float64
#  8   critic_score     9035 non-null   float64
#  9   user_score       8639 non-null   float64
#  10  rating           16567 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ### столбец na_sales eu_sales jp_sales other_sales

# %% [markdown]
# поменяем млн на количество штук и на инт по скольку есть отрицательные значение исправим это тоже

# %%
data['other_sales'].describe()
# Out:
# count    16567.000000
# mean         0.047567
# std          0.187476
# min          0.000000
# 25%          0.000000
# 50%          0.010000
# 75%          0.030000
# max         10.570000
# Name: other_sales, dtype: float64

# %%
data['jp_sales'].describe()
# Out:
# count    16567.000000
# mean         0.078020
# std          0.310068
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: jp_sales, dtype: float64

# %%
data['na_sales'].describe()
# Out:
# count    16567.000000
# mean         0.263975
# std          0.816474
# min          0.000000
# 25%          0.000000
# 50%          0.080000
# 75%          0.240000
# max         41.360000
# Name: na_sales, dtype: float64

# %%
data['eu_sales'].describe()
# Out:
# count    16567.000000
# mean         0.145814
# std          0.505364
# min          0.000000
# 25%          0.000000
# 50%          0.020000
# 75%          0.110000
# max         28.960000
# Name: eu_sales, dtype: float64

# %%
data['na_sales']=(abs(data['na_sales'])*1000000).astype('int')

# %%
data['eu_sales']=(abs(data['eu_sales'])*1000000).astype('int')

# %%
data['jp_sales']=(abs(data['jp_sales'])*1000000).astype('int')

# %%
data['other_sales']=(abs(data['other_sales'])*1000000).astype('int')

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      Wii             2006        Sports  41360000
# 1         super mario bros.      NES             1985      Platform  29080000
# 2            mario kart wii      Wii             2008        Racing  15680000
# 3         wii sports resort      Wii             2009        Sports  15610000
# 4  pokemon red/pokemon blue       GB             1996  Role-Playing  11270000
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating
# 0  28960000   3770000      8450000          76.0         8.0        E
# 1   3580000   6810000       770000           NaN         NaN  Unknown
# 2  12760000   3790000      3290000          82.0         8.3        E
# 3  10930000   3280000      2950000          80.0         8.0        E
# 4   8890000  10220000      1000000           NaN         NaN  Unknown

# %%
data['other_sales'].describe().astype('int')
# Out:
# count       16567
# mean        47567
# std        187476
# min             0
# 25%             0
# 50%         10000
# 75%         30000
# max      10570000
# Name: other_sales, dtype: int64

# %%
data['na_sales'].describe().astype('int')
# Out:
# count       16567
# mean       263974
# std        816473
# min             0
# 25%             0
# 50%         80000
# 75%        240000
# max      41360000
# Name: na_sales, dtype: int64

# %%
data['eu_sales'].describe().astype('int')
# Out:
# count       16567
# mean       145813
# std        505363
# min             0
# 25%             0
# 50%         20000
# 75%        110000
# max      28960000
# Name: eu_sales, dtype: int64

# %%
data['jp_sales'].describe().astype('int')
# Out:
# count       16567
# mean        78020
# std        310068
# min             0
# 25%             0
# 50%             0
# 75%         40000
# max      10220000
# Name: jp_sales, dtype: int64

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       7532
# user_score         7928
# rating                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16567 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16567 non-null  object
#  1   platform         16567 non-null  object
#  2   year_of_release  16567 non-null  int64
#  3   genre            16567 non-null  object
#  4   na_sales         16567 non-null  int64
#  5   eu_sales         16567 non-null  int64
#  6   jp_sales         16567 non-null  int64
#  7   other_sales      16567 non-null  int64
#  8   critic_score     9035 non-null   float64
#  9   user_score       8639 non-null   float64
#  10  rating           16567 non-null  object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 1.5+ MB

# %%
data['sale']=data['na_sales']+data['eu_sales']+data['jp_sales']+data['other_sales']

# %% [markdown]
# в этом разделемы проверили на дубликаты(их не было) и нашли все пропуски заполнив их данными а те которые не получилось заполнить удалили скорректировали типы данных так что бы дальше могли с ними работать и анализировать данные
# пропуски появились из за того что люди наверно на разных платформач для одной и той же игры забыли заполнить данные. в столбце rating некоторым еше не успели прсвоить категорию а некоторые данные могли быть просто утерены.
# добавили столбец sale  суммарные продажи по всем регионам
# поменяли млн на количество штук и на инт по скольку были отрицательные значение исправили это тоже

# %% [markdown]
# data[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      Wii             2006        Sports  41360000
# 1         super mario bros.      NES             1985      Platform  29080000
# 2            mario kart wii      Wii             2008        Racing  15680000
# 3         wii sports resort      Wii             2009        Sports  15610000
# 4  pokemon red/pokemon blue       GB             1996  Role-Playing  11270000
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating  \
# 0  28960000   3770000      8450000          76.0         8.0        E
# 1   3580000   6810000       770000           NaN         NaN  Unknown
# 2  12760000   3790000      3290000          82.0         8.3        E
# 3  10930000   3280000      2950000          80.0         8.0        E
# 4   8890000  10220000      1000000           NaN         NaN  Unknown
#
#        sale
# 0  82540000
# 1  40240000
# 2  35520000
# 3  32770000
# ...

# %% [markdown]
# # Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
data['year_of_release'].describe()
# Out:
# count    16567.000000
# mean      2006.490252
# std          5.862680
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: year_of_release, dtype: float64

# %%
data.groupby('year_of_release')['name'].count().plot(y = 'name', kind= 'bar', figsize = (20,10));

# %% [markdown]
# из графика следует что с начинается эпоха игр и чем дальше тем больше игр начинают релизить)) в 2008 2009 годах был пик релизов игр появились более по 1400 игр в год а с 2011 года начинается спад релизов 2012 год резкый спад я думаю это из за того что вырасло качество игр и стали брать не количеством а качеством (для анализа данных я бы взял срез от 1994 года так как все быстро устаревает и до 1994 года релизов было мало всего 361)

# %%
data['year_of_release'].plot.box(figsize=(20,15))# период 1994-2016
# Out:
# <AxesSubplot:>

# %% [markdown]
# Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
top10_pl=data.groupby('platform').agg({'sale':'sum'}).sort_values(by = 'sale', ascending = False)[:10].index

# %%
pl_y = data.pivot_table(index=['platform','year_of_release'], values = 'sale', aggfunc = 'sum')

# %%
pl_y['years'] =  pl_y.index

# %%
pl_y['years'] = pl_y['years'].apply (lambda row: row[1]).astype('int')

# %%
pl_y
# Out:
#                               sale  years
# platform year_of_release
# 2600     1980             11380000   1980
#          1981             35680000   1981
#          1982             28880000   1982
#          1983              5840000   1983
#          1984               270000   1984
# ...                            ...    ...
# XB       2008               180000   2008
# XOne     2013             18960000   2013
#          2014             54070000   2014
#          2015             60140000   2015
#          2016             26149999   2016
#
# [243 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize =(15,5))
for platform in top10_pl:
    pl_y.loc[platform].plot('years','sale', ax=ax)
ax.legend(top10_pl,prop = {'size':15})
ax.set_xlim([1994,2017])
ax.set_xticks(np.arange(1994,2017))
ax.set_xticklabels(range(1994,2017))
plt.show()

# %% [markdown]
# Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %% [markdown]
# мы видим что каждые примерно 10 лет платформы исчезают и появляются новые видим что только ps4 недавно начял падать по продажам с 2015ого года остальные конкуренты с 2009 2011 года уже падали ps3 тоже посчетаем конкурента хотя ps4 это логическое продолжение ps3. потенциально прибыльныt платформы ps4 одназначно ps3(ps3 100% будет не прибыльно  поскольку есть уже ps4).x360 Wii и конечно же pc который имеет стабильно своих поклоников

# %% [markdown]
# Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# Не учитывайте в работе данные за предыдущие годы.

# %% [markdown]
# думаю актуально будет взять данные за последные 10-11т можно и меньше но не больше так как в играх очень много меняется и очень часто меняется и те платформы которые сейчас сушествуют были созданы не более 11лет назат так что с 2014 ого года начинается актуалное время

# %%
act=data[data['year_of_release']>=2014]

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1689 entries, 31 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1689 non-null   object
#  1   platform         1689 non-null   object
#  2   year_of_release  1689 non-null   int64
#  3   genre            1689 non-null   object
#  4   na_sales         1689 non-null   int64
#  5   eu_sales         1689 non-null   int64
#  6   jp_sales         1689 non-null   int64
#  7   other_sales      1689 non-null   int64
#  8   critic_score     989 non-null    float64
#  9   user_score       1022 non-null   float64
#  10  rating           1689 non-null   object
#  11  sale             1689 non-null   int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 171.5+ KB

# %% [markdown]
# Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
fig,ax = plt.subplots(figsize =(15,10))
sns.boxplot(x = 'platform', 
            y = 'sale',
            data = act,
            ax=ax)
# Out:
# <AxesSubplot:xlabel='platform', ylabel='sale'>

# %%
fig,ax = plt.subplots(figsize =(15,9))
sns.boxplot(x = 'platform', 
            y = 'sale',
            data = act,
            ax=ax,
           showfliers=False)
# Out:
# <AxesSubplot:xlabel='platform', ylabel='sale'>

# %%
top = act['sale']
low = act['sale']
th = top + 2*low
fig, ax = plt.subplots(figsize =(15,5))
sns.boxplot(x = 'platform', 
            y = 'sale',
            data = act.query('sale <= @th'),ax=ax)
# Out:
# <AxesSubplot:xlabel='platform', ylabel='sale'>

# %%
top = act['sale'].quantile(0.75)
low = act['sale'].quantile(0.25)
th = top + 2*low
fig, ax = plt.subplots(figsize =(15,5))
sns.boxplot(x = 'platform', 
            y = 'sale',
            data = act.query('sale <= @th'),ax=ax)
# Out:
# <AxesSubplot:xlabel='platform', ylabel='sale'>

# %% [markdown]
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %%
ps4 = act.query('platform == "PS4"')[['critic_score','user_score','sale']]

# %%
ps4=ps4[ps4['critic_score']!='tbd']
ps4=ps4[ps4['user_score']!='tbd']
#ps4=ps4.astype('int')
ps4.plot(kind="hist",bins=15,figsize=(15,5));

# %%
sns.pairplot(ps4)
plt.show()

# %%
# Корреляционная матрица

sns.heatmap(ps4.corr(),annot=True)
plt.show()

# %% [markdown]
# видим некую несушественную кореллацию между продажами и оценками критиков но она слишком маленькая

# %% [markdown]
# Соотнесите выводы с продажами игр на других платформах.

# %%
act['platform'].unique()
# Out:
# array(['PS4', '3DS', 'XOne', 'WiiU', 'PS3', 'X360', 'PC', 'Wii', 'PSV',
#        'PSP'], dtype=object)

# %%
X360 = act.query('platform == "X360"')[['critic_score','user_score','sale']]
X360=X360[X360['critic_score']!='tbd']
X360=X360[X360['user_score']!='tbd']
#X360=X360.astype('int')
sns.pairplot(X360)
plt.show()

# %% [markdown]
# ps4.plot(kind="hist",bins=15,figsize=(15,5));

# %%
sns.heatmap(X360.corr(),annot=True)
plt.show()

# %%
PS3 = act.query('platform == "PS3"')[['critic_score','user_score','sale']]
PS3=PS3[PS3['critic_score']!='tbd']
PS3=PS3[PS3['user_score']!='tbd']
#PS3=PS3.astype('int')
sns.pairplot(PS3)
plt.show()

# %%
sns.heatmap(PS3.corr(),annot=True)
plt.show()

# %%
Wii = act.query('platform == "Wii"')[['critic_score','user_score','sale']]
Wii=Wii[Wii['critic_score']!='tbd']
Wii=Wii[Wii['user_score']!='tbd']
#Wii=Wii.astype('int')
sns.pairplot(Wii)
plt.show()

# %%
Wii#(((
# Out:
#        critic_score  user_score     sale
# 850            72.0         8.4  2010000
# 2179           73.0         6.1   950000
# 2180           82.0         6.3   950000
# 3611           82.0         4.3   560000
# 7991           47.0         3.9   180000
# 8009           74.0         8.0   180000
# 8941           81.0         5.4   150000
# 13570           NaN         NaN    40000
# 14682           NaN         2.8    30000
# 16144          51.0         5.2    10000
# 16312           NaN         NaN    10000

# %%
sns.heatmap(Wii.corr(),annot=True)
plt.show()

# %%
PC = act.query('platform == "PC"')[['critic_score','user_score','sale']]
PC=PC[PC['critic_score']!='tbd']
PC=PC[PC['user_score']!='tbd']
#PC=PC.astype('int')
sns.pairplot(PC)
plt.show()

# %%
sns.heatmap(PC.corr(),annot=True)
plt.show()

# %% [markdown]
# в  платформах мы не нашлы сушественнойсвязы между продажамы и отзывами

# %% [markdown]
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
act.groupby('genre')['sale'].median().sort_values(ascending=False)
# Out:
# genre
# Shooter         515000
# Sports          180000
# Platform        140000
# Fighting        125000
# Role-Playing    110000
# Simulation      100000
# Action           90000
# Misc             90000
# Racing           90000
# Strategy         60000
# Puzzle           45000
# Adventure        30000
# Name: sale, dtype: int64

# %%
act.groupby('genre')['sale'].median().sort_values(ascending=False).plot(kind='bar');

# %% [markdown]
# видно что люди больше любят и покупают активные игры в жанрах   sports и  shooters а меньше всего puzzle и strategy и adventure

# %%
act.groupby('platform')['sale'].median().sort_values(ascending=False)
# Out:
# platform
# XOne    205000
# WiiU    190000
# PS4     185000
# Wii     180000
# X360    180000
# PS3     110000
# 3DS      90000
# PC       60000
# PSV      40000
# PSP      20000
# Name: sale, dtype: int64

# %% [markdown]
# # Шаг 4. Составьте портрет пользователя каждого региона

# %% [markdown]
# ## Определите для пользователя каждого региона (NA, EU, JP):
# #Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# #Самые популярные жанры (топ-5). Поясните разницу.
# #Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
act.groupby('platform')['na_sales'].sum().sort_values(ascending=False)[:5].plot(kind='pie',y="% sales");

# %%
act.groupby('platform')['eu_sales'].sum().sort_values(ascending=False)[:5].plot(kind='pie',y="% sales");

# %%
act.groupby('platform')['jp_sales'].sum().sort_values(ascending=False)[:5].plot(kind='pie',y="% sales");

# %%
act.groupby('genre')['na_sales'].sum().sort_values(ascending=False)[:5].plot(kind='pie',y="% sales");

# %%
act.groupby('genre')['eu_sales'].sum().sort_values(ascending=False)[:5].plot(kind='pie',y="% sales");

# %%
act.groupby('genre')['jp_sales'].sum().sort_values(ascending=False)[:5].plot(kind='pie',y="% sales");

# %%
act[act['rating']!="Unknown"].groupby('rating')['eu_sales'].sum().sort_values(ascending=False).plot(kind='pie',y="% sales");

# %%
act[act['rating']!="Unknown"].groupby('rating')['na_sales'].sum().sort_values(ascending=False).plot(kind='pie',y="% sales");

# %%
act[act['rating']!="Unknown"].groupby('rating')['jp_sales'].sum().sort_values(ascending=False).plot(kind='pie',y="% sales");

# %%
act.groupby('rating')['na_sales','eu_sales','jp_sales'].sum().plot(kind='bar');
# Out:
# /tmp/ipykernel_333/636448770.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   act.groupby('rating')['na_sales','eu_sales','jp_sales'].sum().plot(kind='bar');

# %% [markdown]
# видем что практически продаетсются те же же самие категории игр только в японии на первом месте категоря Т а не Е. и в японее меньше игр продается чем в европе или тем более в северной америке

# %% [markdown]
# # Шаг 5. Проверьте гипотезы

# %% [markdown]
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# Нулевая гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# Альтернативная гипотеза : Средние пользовательские рейтинги платформ Xbox One и PC разные

# %%
alpha = 0.05 # критический уровень статистической значимости

Xe=act.query('platform=="XOne" & user_score.isna()!=True')['user_score']
PC=act.query('platform=="PC" & user_score.isna()!=True')['user_score']

results = st.ttest_ind(
    Xe, 
    PC)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Средние пользовательские рейтинги платформ Xbox One и PC разные.")
else:
    print("Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.")
# Out:
# p-значение: 0.027373596853303993
# Средние пользовательские рейтинги платформ Xbox One и PC разные.

# %% [markdown]
# Нулевая гипотеза:Средние пользовательские рейтинги жанров Action  и Sports  одинаковые.
#
# Альтернативная гипотеза : Средние пользовательские рейтинги жанров Action  и Sports разные .

# %%
alpha = 0.05 # критический уровень статистической значимости

Action=act.query('genre=="Action" & user_score.isna()!=True')['user_score']
Sports=act.query('genre=="Sports" & user_score.isna()!=True')['user_score']

results = st.ttest_ind(
    Action, 
    Sports)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Средние пользовательские рейтинги жанров Action  и Sports  разные.")
else:
    print("Средние пользовательские рейтинги жанров Action  и Sports  одинаковые.")
# Out:
# p-значение: 3.1534378959897826e-24
# Средние пользовательские рейтинги жанров Action  и Sports  разные.

# %% [markdown]
# # Шаг 6. Общие выводы

# %% [markdown]
# Исходные данные представляют собой  таблицу с 16715 записями и 11 столбцами. При первоначальном анализе было обнаружено больше количество пропусков в столбцах с рейнигом, годом издания игры, оценками критиков и оценками пользователей. В работе используются различные подходы к заполнению недостающих значений с целью включению в выборку для анализа как можно большего количества релевантной информации. В качестве дополнения стоит отметить, что одним из способов заполнения пропусков можно было бы использовать модуль requests для считывания веб-странницы по конкретной игре для конкртеной плафтормы с какого-нибудь популярного сайта с оценками игр, например с metacritic.com, и использовать любой парсер web страниц, например beautifulsoup, для заполнения пропусков, чтобы ещё больше повысить точность исследования, особенно для игр до 2007 года.
#
# Для заполнения пропусков использовалась средние значения, сгруппированные по играм, так как одни и теже игры выходят на несколько платформ и заполнение пропусков медианами является допустимым решением, так как ни год реализации, ни оценки критоков существенно не отличаются у одноимённых игр. Для заполнения года реализация также использовались регулярные выражения для вычлинения года выпуска игры из её наименования. Как правило, игра выходит на год раньше, чем указано в её имени
#
# В различные года на рынке доминировали различные платформы, но набольшие продажи за всё время показала PS2. Как было выяснено из анализа распределения продаж игр на различных платформах по годам, медианное время жизни платформы составляет 10 лет
#
# В различные годы пользователей предпочитали различные платформы, но в период с 2007 по 2016 пользователей в большей степени интересовали Wii (2007-2009), Xbox 360 (2010), PS3 (2011-2013), PS4(2014-2016). При анализе продаж на различные платформы было выяснено, что хоть разброс значений у различных платформ и сильно отличается (игровые индустрии выпускают хиты для отдельных платформ) средние значения для всех платформ почти одинаковые: 250 тыс для стационарных консолей и 125 тыс для портативных и ПК
#
# При анализе корреляции между оценками и продажами было выяснено, оценки пользователей вообще не коррелируют с продажами, а оценки критиков лишь на 0.39, что также является недостаточным для составления рекламной кампании.
#
# Из года в год самыми популярными жанрами остаются игры в жанрах  action sports и shooters.
#
# Портрет пользователей для различных регионов имеет преимущественно одинаковый вид для всего мира. Однако в Японии люди склонны играть на портативных консолях и поэтому для них характерным жанром игр является RPG и именно японцы предпочитают игры для Teen в большей степени, по сравнению с остальным миром.
#
# При анализе гипотез было выяснено, что оценки пользователей для платформ Xbox One и PC разные и оценки для разных игровых жанров у пользователей отличаются
